# %%
### 🔧 TAREA
#Antes de entrenar la red neuronal, modifica los hiperparámetros en `config.yaml`, especialmente:
#- `hidden_layers`: cambia el número de capas o neuronas.
#- `activation`: prueba funciones como `tanh` o `elu`.
#- `epochs`: aumenta o reduce el número de épocas.
#
#Luego, vuelve a ejecutar este notebook y observa cómo cambia el rendimiento.

# %%
import os
print(os.getcwd())

import sys
sys.path.append("../src")

import train
import model
import utils
import evaluate as ev
import pandas as pd
import numpy as np
import yaml
# Out:
# c:\Users\jota_\OneDrive\Escritorio\Magister\Deep Learning\DeepNeuralNetworkUSS\Projects\Credit\notebooks

# %%
# 🔧 Cargar configuración
config = train.load_config("../config2.yaml")

# 📦 Cargar y preparar los datos
X, y = train.load_data("../data/credit_clean_wo_outliers.csv")
X_train, X_test, y_train, y_test = train.preprocess(X, y, config)

# %%
# 🧠 Construir el modelo
input_dim = X_train.shape[1]
nn_model = model.build_model(config, input_dim)
# Out:
# C:\Users\jota_\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# 🚀 Entrenar el modelo
history = train.train_model(nn_model, X_train, y_train, config)
# Out:
# Epoch 1/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6924 - loss: 0.6512 - val_accuracy: 0.7135 - val_loss: 0.6048
# Epoch 2/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 875us/step - accuracy: 0.7301 - loss: 0.5929 - val_accuracy: 0.7336 - val_loss: 0.5684
# Epoch 3/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 862us/step - accuracy: 0.7463 - loss: 0.5544 - val_accuracy: 0.7475 - val_loss: 0.5468
# Epoch 4/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.7531 - loss: 0.5434 - val_accuracy: 0.7502 - val_loss: 0.5417
# Epoch 5/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 863us/step - accuracy: 0.7680 - loss: 0.5257 - val_accuracy: 0.7514 - val_loss: 0.5335
# Epoch 6/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 892us/step - accuracy: 0.7611 - loss: 0.5222 - val_accuracy: 0.7443 - val_loss: 0.5431
# Epoch 7/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 912us/step - accuracy: 0.7584 - loss: 0.5251 - val_accuracy: 0.7521 - val_loss: 0.5262
# Epoch 8/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 894us/step - accuracy: 0.7601 - loss: 0.5199 - val_accuracy: 0.7516 - val_loss: 0.5244
# Epoch 9/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.7603 - loss: 0.5179 - val_accuracy: 0.7525 - val_loss: 0.5236
# Epoch 10/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 873us/step - accuracy: 0.7576 - loss: 0.5222 - val_accuracy: 0.7562 - val_loss: 0.5184
# Epoch 11/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - accuracy: 0.7680 - loss: 0.5071 - val_accuracy: 0.7587 - val_loss: 0.5220
# Epoch 12/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 907us/step - accuracy: 0.7592 - loss: 0.5157 - val_accuracy: 0.7532 - val_loss: 0.5261
# Epoch 13/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 855us/step - accuracy: 0.7663 - loss: 0.5106 - val_accuracy: 0.7489 - val_loss: 0.5266
# Epoch 14/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - accuracy: 0.7675 - loss: 0.5115 - val_accuracy: 0.7530 - val_loss: 0.5207
# Epoch 15/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 921us/step - accuracy: 0.7651 - loss: 0.5080 - val_accuracy: 0.7566 - val_loss: 0.5169
# Epoch 16/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 951us/step - accuracy: 0.7661 - loss: 0.5087 - val_accuracy: 0.7591 - val_loss: 0.5148
# Epoch 17/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 929us/step - accuracy: 0.7646 - loss: 0.5038 - val_accuracy: 0.7589 - val_loss: 0.5143
# Epoch 18/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 894us/step - accuracy: 0.7631 - loss: 0.5104 - val_accuracy: 0.7582 - val_loss: 0.5157
# Epoch 19/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 883us/step - accuracy: 0.7667 - loss: 0.5032 - val_accuracy: 0.7591 - val_loss: 0.5149
# Epoch 20/20
# 548/548 ━━━━━━━━━━━━━━━━━━━━ 1s 907us/step - accuracy: 0.7663 - loss: 0.5006 - val_accuracy: 0.7557 - val_loss: 0.5167

# %%
# 💾 Guardar modelo entrenado
utils.save_model(nn_model, path="../models/nn_model-drop.keras")
# Out:
# ✅ Modelo guardado en ../models/nn_model-drop.keras

# %%
# 📈 Visualizar evolución del entrenamiento
utils.plot_training_history(history, model_name="Red Neuronal")

# %% [markdown]
# Con la capa Dropout se observa que en el grafico de prescion, ambas curvas son mas suaves y estables, de igual forma en la perdida. Se muestra un entrenamiento mása regularizado por la menor diferencia entre entenamiento y validación.
